# %% [markdown]
# # GirlsinSight
# ### Version 1.0.1
# **Created on:** December 31, 2024
# **Author:** Jason G. Karlin
# **Contact:** [karlin@iii.u-tokyo.ac.jp](mailto:karlin@iii.u-tokyo.ac.jp)

# %% [markdown]
# ## Instructions: Setting Up the Gemini AI API Key
#
# To use Gemini AI, follow these steps to generate and store your API key securely:
#
# ### Step 1: Generate Your API Key
# 1. Open this link in your browser: [Gemini AI API Key Page](https://aistudio.google.com/app/apikey).
# 2. Sign in with your Google account.
# 3. Click on the **"Generate API Key"** button.
# 4. Copy the generated API key.
#
# ### Step 2: Store the API Key in Colab Secrets
# 1. In your Colab notebook, click on the **key icon** in the left-hand sidebar (this opens the Secrets manager).
# 2. Click **"Add new secret"**.
# 3. In the **Name** field, type `GEMINI_API_KEY`.
# 4. In the **Value** field, paste your Gemini AI API key.
# 5. Toggle **Notebook** access to enable the key

# %% [markdown]
# #### Test Gemini API Key

# %%
from google.colab import userdata

# Retrieve the API key from Colab Secrets
stored_gemini_api_key = userdata.get("GEMINI_API_KEY")

if stored_gemini_api_key:
    print("Successfully retrieved Gemini API key from Colab Secrets.")
    headers = {"Authorization": f"Bearer {stored_gemini_api_key}"}
    print("You can now use this API key in your Gemini API requests.")
else:
    raise ValueError("Gemini API key not found in Colab Secrets. Please ensure it is stored manually.")
# Out:
# Successfully retrieved Gemini API key from Colab Secrets.
# You can now use this API key in your Gemini API requests.

# %% [markdown]
# #### Install Required Python Libraries and dependencies

# %%
# !pip install openai anthropic google-generativeai pandas requests beautifulsoup4 openpyxl matplotlib seaborn
# !apt-get install -y fonts-noto-cjk
# !fc-cache -fv
# !rm -rf ~/.cache/matplotlib

# %% [markdown]
# #### **Run the script below**
# #### * Ensure that the girlsinsight.v1.0.1.colab.py file has been uploaded

# %%
# %run girlsinsight.v1.0.1.colab.py
# Out:
# *** GirlsinSight ***
#
# 1. トピックのURLを入力
# 2. トピックを検索
# 3. 終了する
#
# 選択肢を入力してください: 1
# トピックのURLを入力してください: https://girlschannel.net/topics/5480251/
#
# 結果はどちらの言語がよろしいですか： 1. 日本語 2. 英語： 1
#
# AIを選択してください (要約)： 1. OpenAI 2. Anthropic 3. Gemini： 3
#
# AIを選択してください (感情分析)： 1. OpenAI 2. Anthropic 3. Gemini： 3
#
# 入力されたURL: https://girlschannel.net/topics/5480251/
# 153/153のコメント
#
# トピック 1:
# 【緊急】婚活初デートプラン
#
#
# 概要:
# この投稿は、婚活で知り合った相手との初めてのデートを正月に行うことになった相談である。投稿者は、正月期間で店が閉まっている可能性を懸念しており、デートプランの代替案や注意点についてアドバイスを求めている。緊急性を表すタイトルから、投稿者がデートプランに困惑し、早急な解決を望んでいることがわかる。つまり、投稿の意図は、初デートを成功させるために、具体的なアドバイスや代替案を求めることにある。
#
#
# 出典がありません
#
# 初コメント: 2024年12月30日 19:44
# 最終コメント: 2024年12月31日 18:14
# 期間: 22時間29分39秒
# 最も投票数の多いコメント:
# ∙ コメント: ドライブはやめておけ
#   点数: 204
#
# ∙ コメント: ドライブはやめておけ
#   点数: 204
#
# ∙ コメント: 初デートでドライブとか女側も断るべきだし 男側も自重するべきだと思う
#   点数: 151
#
# 　平均比率: 0.98
# 　中央値比率: 0.99
# 　標準偏差: 0.01
# 　合意の度合: 9.93 (0-10)
#
# 最も低評価のコメント:
# ∙ コメント: 信州！
#   点数: -7
#
# ∙ コメント: 離婚しなおばさんだって、好きな人の気を引くためにバッチリオサレしてた時代もあるのよ。
#   点数: -6
#
# ∙ コメント: 離婚しなおばさんだって、好きな人の気を引くためにバッチリオサレしてた時代もあるのよ。
#   点数: -6
#
# 　平均比率: 0.35
# 　中央値比率: 0.33
# 　標準偏差: 0.23
# 　不一致の度合: 8.54
#
# 評価:
# ガールズチャンネルの【緊急】婚活初デートプランに関するコメント群を分析すると、コミュニティ全体として、初デートでのドライブという提案に対して非常に強い警戒心と否定的な感情を抱いていることが明らかになります。最も多く賛同を集めたコメントは、「ドライブはやめておけ」という直接的な拒否であり、この意見が複数回投稿されていることから、この警戒心が広く共有されていることがわかります。「初デートでドライブとか女側も断るべきだし男側も自重するべきだと思う」というコメントも、ドライブが適切ではないという考えをさらに強調しています。多くのユーザーは、初対面の相手とのドライブは危険であり、避けるべきだと感じています。「初デートで車って危険じゃない？」という問いかけも複数見られ、この不安が単なる個人的な懸念ではなく、社会的な認識として共有されていることが示唆されます。
#
# さらに、初デートの理想的なプランとして、電車で行ける場所で、神社参拝やカフェ、軽食などが提案されています。「電車で行ける場所は無理なの？神社にお参り行ってどこかでカフェやご飯で十分かと」という意見は、初対面の人との距離感を考慮し、安全で穏やかなデートを望む心理を表しています。また、「映画か買い物してお茶か軽く食事でいいんじゃね？」や「ランチだけとかじゃないの？！」といったコメントからは、過度に時間を要したり、親密になりすぎるようなデートは避けるべきだという共通認識が見て取れます。
#
# 一方で、反対意見としてダウンボートされたコメントを見てみると、「信州！」という具体的な場所を提案するものや、「三社参りと足湯」といったアクティブなデートプランが挙げられています。これらのコメントが支持されなかった背景には、初対面の相手との関係性や安全面への配慮が欠けているという認識があると考えられます。「離婚しなおばさんだって、好きな人の気を引くためにバッチリオサレしてた時代もあるのよ」といったコメントは、初デートへの意気込みを語るものの、現在の婚活の文脈では、過度なアピールよりも安全性が重視されていることがわかります。「旦那との初回ディナーだったわ」というコメントは、過去の成功体験に基づくものであり、現在多くの人が重視する「安全」や「気軽さ」とは異なる価値観を反映しているため、共感を得られなかったのでしょう。
#
# 「だよね。主が幾つか分からないけど怖いもの知らずと言うか、世間知らずというかさ…これだけ色んな事件があるのに初デートで車に乗る心理が分からない」というコメントは、社会情勢への意識の欠如を指摘し、初デートでのドライブという行為が、現代社会においては軽率な行為とみなされていることを示唆しています。これらのコメント全体から、ガールズチャンネルのユーザーは、婚活初デートにおいて、危険を避け、相手との距離感を慎重に見極めようとする傾向が強いことがわかります。また、過去の経験や個人的な意見よりも、社会的な安全基準や一般的なマナーを重視する傾向も見られます。このような意見が反映される背景には、日本のソーシャルメディア環境において、匿名性を利用した率直な意見交換が盛んであるという点も影響していると考えられます。
#
# Sentiment: Negative
# Score: 2
#
#
# 評価されたコメント数: 22
# 総合コメント数: 241
#
# 全体的な合意度: 9.24 (0-10)
# ————————————————————————————
